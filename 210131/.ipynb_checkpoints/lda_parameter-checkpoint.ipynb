# %%
# abstracts + meta_keywords 합쳐서 LDA 돌려보기

# %%
import pandas as pd
from gensim import corpora
from nltk import word_tokenize, pos_tag

# %%
df = pd.read_csv('/Users/geoffrey/jupyter/lesson/201227/crawling_result.csv', index_col=0)

# %%
df.head()
# Out:
#                                               titles  \
# 0  Trends of articles published in theKoreanJourn...
# 1  A systematic review of the accuracy and effici...
# 2  Renovating the history of thekoreanjournalofor...
# 3  Clustering of craniofacial patterns inKoreanch...
# 4  The effect of western adaptation of Hispanic-A...
#
#                                        links  \
# 0  https://pubmed.ncbi.nlm.nih.gov/28127541/
# 1  https://pubmed.ncbi.nlm.nih.gov/31149604/
# 2  https://pubmed.ncbi.nlm.nih.gov/23112923/
# 3  https://pubmed.ncbi.nlm.nih.gov/28670566/
# 4  https://pubmed.ncbi.nlm.nih.gov/24511513/
#
#                                            abstracts  \
# 0                                              Error
# 1  We are currently living in an era where the us...
# 2                                              Error
# 3  Objective:The purpose of this study was to inv...
# 4  Objective:To determine Korean facial profile p...
#
#                                           meta_names  \
# 0                                    Hyung-Seon Baik
# 1  Lidia Galan-Lopez,Jorge Barcia-Gonzalez,Eliseo...
# 2                                         Ki-Soo Lee
# 3  Stephanie Maritza Anderson,Hoi-Jeong Lim,Ki-Be...
# 4  Leo Toureno,Yoon-Ah Kook,Mohamed Bayome,Jae Hy...
#
#                                        meta_keywords
# 0                                              Error
# 1  Clear aligners,Invisalign®,Invisible orthodont...
# 2                                              Error
# 3  Adenotonsillar hypertrophy,Cluster analysis,Cr...
# 4  Hispanic-American,Korean facial profile,Orthod...

# %%
# meta_keywords를 word_tokenize 할 것인가? 아니면 , 기준으로 나눌 것인가?
tmp = df.meta_keywords[4]
print(f"word_tokenize : f{word_tokenize(tmp)}")
print(f"',' 기준 split : f{tmp.split(',')}")
# Out:
# word_tokenize : f['Hispanic-American', ',', 'Korean', 'facial', 'profile', ',', 'Orthodontics', ',', 'Western', 'adaptation', '.']
# ',' 기준 split : f['Hispanic-American', 'Korean facial profile', 'Orthodontics', 'Western adaptation.']

# %%
# f-string을 이용한 print법
a = 'apple, banana'

print(f'내가 제일 좋아하는 과일은 {a} 입니다')
# Out:
# 내가 제일 좋아하는 과일은 apple, banana 입니다

# %%
# f-string을 이용한 csv 파일 읽기
file_name = 'crawling_result'
pd.read_csv(f"/Users/geoffrey/jupyter/lesson/201227/{file_name}.csv", index_col=0).head()
# Out:
#                                               titles  \
# 0  Trends of articles published in theKoreanJourn...
# 1  A systematic review of the accuracy and effici...
# 2  Renovating the history of thekoreanjournalofor...
# 3  Clustering of craniofacial patterns inKoreanch...
# 4  The effect of western adaptation of Hispanic-A...
#
#                                        links  \
# 0  https://pubmed.ncbi.nlm.nih.gov/28127541/
# 1  https://pubmed.ncbi.nlm.nih.gov/31149604/
# 2  https://pubmed.ncbi.nlm.nih.gov/23112923/
# 3  https://pubmed.ncbi.nlm.nih.gov/28670566/
# 4  https://pubmed.ncbi.nlm.nih.gov/24511513/
#
#                                            abstracts  \
# 0                                              Error
# 1  We are currently living in an era where the us...
# 2                                              Error
# 3  Objective:The purpose of this study was to inv...
# 4  Objective:To determine Korean facial profile p...
#
#                                           meta_names  \
# 0                                    Hyung-Seon Baik
# 1  Lidia Galan-Lopez,Jorge Barcia-Gonzalez,Eliseo...
# 2                                         Ki-Soo Lee
# 3  Stephanie Maritza Anderson,Hoi-Jeong Lim,Ki-Be...
# 4  Leo Toureno,Yoon-Ah Kook,Mohamed Bayome,Jae Hy...
#
#                                        meta_keywords
# 0                                              Error
# 1  Clear aligners,Invisalign®,Invisible orthodont...
# 2                                              Error
# 3  Adenotonsillar hypertrophy,Cluster analysis,Cr...
# 4  Hispanic-American,Korean facial profile,Orthod...

# %%
# 'Error' 제외하기
df = df[df.abstracts != 'Error']
df = df[df.meta_keywords != 'Error']

# index reset 해주기
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#                                               titles  \
# 0  A systematic review of the accuracy and effici...
# 1  Clustering of craniofacial patterns inKoreanch...
# 2  The effect of western adaptation of Hispanic-A...
# 3  Predictors of midpalatal suture expansion by m...
# 4  Part I. What drivesKoreanadults to seek orthod...
#
#                                        links  \
# 0  https://pubmed.ncbi.nlm.nih.gov/31149604/
# 1  https://pubmed.ncbi.nlm.nih.gov/28670566/
# 2  https://pubmed.ncbi.nlm.nih.gov/24511513/
# 3  https://pubmed.ncbi.nlm.nih.gov/31815104/
# 4  https://pubmed.ncbi.nlm.nih.gov/33144525/
#
#                                            abstracts  \
# 0  We are currently living in an era where the us...
# 1  Objective:The purpose of this study was to inv...
# 2  Objective:To determine Korean facial profile p...
# 3  Objective:We sought to determine the predictor...
# 4  Objective:To develop a standardized instrument...
#
#                                           meta_names  \
# 0  Lidia Galan-Lopez,Jorge Barcia-Gonzalez,Eliseo...
# 1  Stephanie Maritza Anderson,Hoi-Jeong Lim,Ki-Be...
# 2  Leo Toureno,Yoon-Ah Kook,Mohamed Bayome,Jae Hy...
# 3  Hyerin Shin,Chung-Ju Hwang,Kee-Joon Lee,Yoon J...
# 4  Min-Hee Oh,Eun-A Kim,Ae-Hyun Park,MinSoo Kim,J...
#
#                                        meta_keywords
# 0  Clear aligners,Invisalign®,Invisible orthodont...
# 1  Adenotonsillar hypertrophy,Cluster analysis,Cr...
# 2  Hispanic-American,Korean facial profile,Orthod...
# 3  Adult treatment,Expansion,Miniscrew-assisted r...
# 4  Adult orthodontic treatment,Perception,Reliabi...

# %%
# 필요 없는 문자 지워주기
def delete_colon_words(x):
    x = x.replace('Objective:', '')
    x = x.replace('Results:', '')
    x = x.replace('Methods:', '')
    x = x.replace('Conclusions:', '')
    return x

# 형용사, 명사, 고유명사를 뽑는 함수 만들어주기
def extract_pos(x):
    tokenized = word_tokenize(x)
    tmp = []
    pos_taged = pos_tag(tokenized)
    for (word, pos) in pos_taged:
        if pos in ['NN', 'JJ', 'NNP']:
            tmp.append(word)
    
    return tmp

# %%
# pandas dataframe에는 map function을 사용할 수 없음! 
# df.map(extract_pos)  ->  (에러 발생)
# pandas series 형식에만 사용 가능함

df.abstracts = df.abstracts.map(delete_colon_words)
df.abstracts = df.abstracts.map(extract_pos)

# %%
df.abstracts
# Out:
# 0      [era, use, computer-aided, design/computer-aid...
# 1      [purpose, study, craniofacial, Korean, snoring...
# 2      [Korean, facial, profile, lip, position, Hispa...
# 3      [midpalatal, suture, expansion, miniscrew-assi...
# 4      [standardized, instrument, level, cognition, o...
#                              ...
# 361    [purpose, study, soft, tissue, thickness, male...
# 362    [study, temporomandibular, joint, TMJ, condyle...
# 363    [Brazilian, girl, chief, complaint, protrusive...
# 364    [incisor, position, bony, support, Class, II, ...
# 365    [19-year-old, woman, dental, clinic, anterior,...
# Name: abstracts, Length: 366, dtype: object

# %%
print(df.abstracts[1])
print("\n\n")
print(df.meta_keywords[1])
# Out:
# ['purpose', 'study', 'craniofacial', 'Korean', 'snoring', 'adenotonsillar', 'hypertrophy', 'ATH', 'characteristic', 'age', 'snoring', 'ATH', 'age', 'range', 'study', 'age', '5-6', '7-8', '9-10', 'cephalometric', 'analysis', 'sagittal', 'vertical', 'skeletal', 'individual', 'Class', 'II', 'III', 'normodivergent', 'hypodivergent', 'hyperdivergent', 'Cluster', 'analysis', 'cephalometric', 'principal', 'addition', 'age', 'factor', 'heterogeneous', 'craniofacial', 'relation', 'age', 'cluster', '%', '5-8', 'skeletal', 'Class', 'Class', 'II', 'hyperdivergent', 'pattern', 'cluster', '%', 'Class', 'II', 'hyperdivergent', 'pattern', '%', 'Class', 'III', 'hyperdivergent', 'pattern', 'study', 'craniofacial', 'Korean', 'snoring', 'ATH', 'characteristic', 'age', 'dominant', 'sagittal', 'skeletal', 'discrepancy', 'hyperdivergent', 'vertical', 'discrepancy', 'evident']
#
#
#
# Adenotonsillar hypertrophy,Cluster analysis,Craniofacial pattern,Snoring.

# %%
pd.concat([df.abstracts, df.links], axis=1)
# Out:
#                                              abstracts  \
# 0    [era, use, computer-aided, design/computer-aid...
# 1    [purpose, study, craniofacial, Korean, snoring...
# 2    [Korean, facial, profile, lip, position, Hispa...
# 3    [midpalatal, suture, expansion, miniscrew-assi...
# 4    [standardized, instrument, level, cognition, o...
# ..                                                 ...
# 361  [purpose, study, soft, tissue, thickness, male...
# 362  [study, temporomandibular, joint, TMJ, condyle...
# 363  [Brazilian, girl, chief, complaint, protrusive...
# 364  [incisor, position, bony, support, Class, II, ...
# 365  [19-year-old, woman, dental, clinic, anterior,...
#
#                                          links
# 0    https://pubmed.ncbi.nlm.nih.gov/31149604/
# 1    https://pubmed.ncbi.nlm.nih.gov/28670566/
# 2    https://pubmed.ncbi.nlm.nih.gov/24511513/
# 3    https://pubmed.ncbi.nlm.nih.gov/31815104/
# 4    https://pubmed.ncbi.nlm.nih.gov/33144525/
# ..                                         ...
# 361  https://pubmed.ncbi.nlm.nih.gov/23112928/
# 362  https://pubmed.ncbi.nlm.nih.gov/24228235/
# 363  https://pubmed.ncbi.nlm.nih.gov/25309867/
# 364  https://pubmed.ncbi.nlm.nih.gov/23814708/
# 365  https://pubmed.ncbi.nlm.nih.gov/25473649/
#
# [366 rows x 2 columns]

# %%
# pandas dataframe에는 apply를 사용하면 함수를 적용할 수 있음! 
# 복수 개의 칼럼에 적용할 때 쓰는 것

df.head()

# abstracts : 이미 list 형태
# meta_keywords : 하나의 string 형태

# def concat_abstracts_keywords(abstract, meta_keyword):
# Out:
#                                               titles  \
# 0  A systematic review of the accuracy and effici...
# 1  Clustering of craniofacial patterns inKoreanch...
# 2  The effect of western adaptation of Hispanic-A...
# 3  Predictors of midpalatal suture expansion by m...
# 4  Part I. What drivesKoreanadults to seek orthod...
#
#                                        links  \
# 0  https://pubmed.ncbi.nlm.nih.gov/31149604/
# 1  https://pubmed.ncbi.nlm.nih.gov/28670566/
# 2  https://pubmed.ncbi.nlm.nih.gov/24511513/
# 3  https://pubmed.ncbi.nlm.nih.gov/31815104/
# 4  https://pubmed.ncbi.nlm.nih.gov/33144525/
#
#                                            abstracts  \
# 0  [era, use, computer-aided, design/computer-aid...
# 1  [purpose, study, craniofacial, Korean, snoring...
# 2  [Korean, facial, profile, lip, position, Hispa...
# 3  [midpalatal, suture, expansion, miniscrew-assi...
# 4  [standardized, instrument, level, cognition, o...
#
#                                           meta_names  \
# 0  Lidia Galan-Lopez,Jorge Barcia-Gonzalez,Eliseo...
# 1  Stephanie Maritza Anderson,Hoi-Jeong Lim,Ki-Be...
# 2  Leo Toureno,Yoon-Ah Kook,Mohamed Bayome,Jae Hy...
# 3  Hyerin Shin,Chung-Ju Hwang,Kee-Joon Lee,Yoon J...
# 4  Min-Hee Oh,Eun-A Kim,Ae-Hyun Park,MinSoo Kim,J...
#
#                                        meta_keywords
# 0  Clear aligners,Invisalign®,Invisible orthodont...
# 1  Adenotonsillar hypertrophy,Cluster analysis,Cr...
# 2  Hispanic-American,Korean facial profile,Orthod...
# 3  Adult treatment,Expansion,Miniscrew-assisted r...
# 4  Adult orthodontic treatment,Perception,Reliabi...

# %%
## 함수를 만들기 전 테스트
abstract = df.abstracts[3]
meta_keyword = df.meta_keywords[3]
meta_keyword = meta_keyword.replace('.', '')

meta_keyword = meta_keyword.split(',')

# list 와 list를 더하면 하나의 list로 합쳐짐
print(abstract + meta_keyword)
# Out:
# ['midpalatal', 'suture', 'expansion', 'miniscrew-assisted', 'rapid', 'palatal', 'expansion', 'MARPE', 'young', 'following', 'possible', 'chronological', 'age', 'palate', 'length', 'depth', 'midpalatal', 'suture', 'maturation', 'MPSM', 'stage', 'midpalatal', 'suture', 'density', 'MPSD', 'ratio', 'sella-nasion', 'SN', 'plane', 'MP', 'angle', 'indicator', 'vertical', 'skeletal', 'pattern', 'point', 'A-nasion-point', 'B', 'ANB', 'angle', 'anteroposterior', 'skeletal', 'classification', 'mean', 'age', 'underwent', 'MARPE', 'treatment', 'palate', 'length', 'depth', 'MPSM', 'stage', 'MPSD', 'ratio', 'initial', 'cone-beam', 'tomography', 'SN-MP', 'angle', 'ANB', 'lateral', 'midpalatal', 'suture', 'ratio', 'midpalatal', 'suture', 'width', 'periapical', 'radiographs', 'MARPE', 'expansion', 'Statistical', 'entire', 'patient', 'group', 'sex', 'vertical', 'skeletal', 'pattern', 'anteroposterior', 'skeletal', 'classification', 'entire', 'patient', 'group', 'midpalatal', 'suture', 'ratio', 'significant', 'negative', 'age', 'palate', 'length', 'MPSM', 'stage', 'r', '=', '-0.506', '-0.494', '-0.746', 'allp', '<', 'subgroup', 'strong', 'negative', 'correlation', 'palate', 'depth', 'skeletal', 'Class', 'II', 'subgroup', 'r', '=', '-0.900', 'p', '<', 'study', 'age', 'palate', 'length', 'MPSM', 'stage', 'midpalatal', 'suture', 'expansion', 'MARPE', 'young', 'Adult treatment', 'Expansion', 'Miniscrew-assisted rapid palatal expansion', 'Predictors']

# %%
df.head()
# Out:
#                                               titles  \
# 0  A systematic review of the accuracy and effici...
# 1  Clustering of craniofacial patterns inKoreanch...
# 2  The effect of western adaptation of Hispanic-A...
# 3  Predictors of midpalatal suture expansion by m...
# 4  Part I. What drivesKoreanadults to seek orthod...
#
#                                        links  \
# 0  https://pubmed.ncbi.nlm.nih.gov/31149604/
# 1  https://pubmed.ncbi.nlm.nih.gov/28670566/
# 2  https://pubmed.ncbi.nlm.nih.gov/24511513/
# 3  https://pubmed.ncbi.nlm.nih.gov/31815104/
# 4  https://pubmed.ncbi.nlm.nih.gov/33144525/
#
#                                            abstracts  \
# 0  [era, use, computer-aided, design/computer-aid...
# 1  [purpose, study, craniofacial, Korean, snoring...
# 2  [Korean, facial, profile, lip, position, Hispa...
# 3  [midpalatal, suture, expansion, miniscrew-assi...
# 4  [standardized, instrument, level, cognition, o...
#
#                                           meta_names  \
# 0  Lidia Galan-Lopez,Jorge Barcia-Gonzalez,Eliseo...
# 1  Stephanie Maritza Anderson,Hoi-Jeong Lim,Ki-Be...
# 2  Leo Toureno,Yoon-Ah Kook,Mohamed Bayome,Jae Hy...
# 3  Hyerin Shin,Chung-Ju Hwang,Kee-Joon Lee,Yoon J...
# 4  Min-Hee Oh,Eun-A Kim,Ae-Hyun Park,MinSoo Kim,J...
#
#                                        meta_keywords
# 0  Clear aligners,Invisalign®,Invisible orthodont...
# 1  Adenotonsillar hypertrophy,Cluster analysis,Cr...
# 2  Hispanic-American,Korean facial profile,Orthod...
# 3  Adult treatment,Expansion,Miniscrew-assisted r...
# 4  Adult orthodontic treatment,Perception,Reliabi...

# %%
# 아래 두 인자를 받는 함수 선언
# abstract : abstracts 칼럼의 각각의 행
# meta_keyword : meta_keywords 칼럼의 각각의 행
def concat_abstracts_keywords(abstract, meta_keyword):

    meta_keyword = meta_keyword.replace('.', '')
    meta_keyword = meta_keyword.split(',')

    result = abstract + meta_keyword
    return result

# %%
tmp = ['A','B']

def lower(x):
    return x.lower()

list(map(lambda x: lower(x), tmp))
# Out:
# ['a', 'b']

# %%
df['docs'] = df.apply(lambda x: concat_abstracts_keywords(x['abstracts'], x['meta_keywords']), axis=1)

# %%
docs = df['docs']
docs
# Out:
# 0      [era, use, computer-aided, design/computer-aid...
# 1      [purpose, study, craniofacial, Korean, snoring...
# 2      [Korean, facial, profile, lip, position, Hispa...
# 3      [midpalatal, suture, expansion, miniscrew-assi...
# 4      [standardized, instrument, level, cognition, o...
#                              ...
# 358    [purpose, study, soft, tissue, thickness, male...
# 359    [study, temporomandibular, joint, TMJ, condyle...
# 360    [Brazilian, girl, chief, complaint, protrusive...
# 361    [incisor, position, bony, support, Class, II, ...
# 362    [19-year-old, woman, dental, clinic, anterior,...
# Name: docs, Length: 363, dtype: object

# %% [markdown]
# ### 번외 : 시간 체크하는 방법
# - 마크다운 문법 참조
#    - https://gist.github.com/ihoneymon/652be052a0727ad59601
# - 마크다운은 화면 상단 툴바에서 code -> markdown으로 변경 (단축키 m)
# - code -> markdown 단축키는 y

# %%
# %%timeit -n 500 -r 10

# 500회 10번 돌려라
# jupyter notebook cell에서만 먹히는 방법!
tmp_docs = []
for i, x in enumerate(df['abstracts']):
    meta_keyword = df.meta_keywords[i].replace('.', '')
    meta_keyword = meta_keyword.split(',')
    tmp_docs.append(x + meta_keyword)

# %%
# %%timeit -n 500 -r 10

df.apply(lambda x: concat_abstracts_keywords(x['abstracts'], x['meta_keywords']), axis=1)
# Out:
# 6.79 ms ± 180 µs per loop (mean ± std. dev. of 10 runs, 500 loops each)

# %%
# 전통적인 time check 방법

import time

start = time.time()

for i in range(5):
    time.sleep(1)

print(f"걸린 시간 : {time.time() - start}")
# Out:
# 걸린 시간 : 5.013577938079834

# %%
# %%time

# jupyter notebook에서 쉽게 타임 체크할 수 있는 방법

for i in range(5):
    time.sleep(1)
# Out:
# CPU times: user 759 µs, sys: 1.13 ms, total: 1.89 ms
# Wall time: 5.02 s

# %% [markdown]
# ### 정수 인코딩 및 lda 모델 돌려보기

# %%
dictionary = corpora.Dictionary(docs)
corpus = [dictionary.doc2bow(doc) for doc in docs]

# %%
# %%time

# lda_model, LdaModel : snake_case, CamelCase
from gensim.models.ldamodel import LdaModel

NUM_TOPICS = 5
ldamodel = LdaModel(corpus=corpus,
                    id2word=dictionary,
                    num_topics=NUM_TOPICS,
                    
                    passes=15)

# %%
# 알 수 있는 것 1
for i, topic_list in enumerate(ldamodel[corpus]):
    print(f"{i}번째 문서의 토픽 분포는 {topic_list}")
# Out:
# 0번째 문서의 토픽 분포는 [(0, 0.98884934)]
# 1번째 문서의 토픽 분포는 [(0, 0.9901228)]
# 2번째 문서의 토픽 분포는 [(1, 0.77940875), (3, 0.21265665)]
# 3번째 문서의 토픽 분포는 [(0, 0.9939365)]
# 4번째 문서의 토픽 분포는 [(1, 0.9905401)]
# 5번째 문서의 토픽 분포는 [(0, 0.32685056), (3, 0.666242)]
# 6번째 문서의 토픽 분포는 [(3, 0.99326056)]
# 7번째 문서의 토픽 분포는 [(0, 0.6084417), (3, 0.38437167)]
# 8번째 문서의 토픽 분포는 [(0, 0.9377501), (1, 0.05390742)]
# 9번째 문서의 토픽 분포는 [(1, 0.9935836)]
# 10번째 문서의 토픽 분포는 [(0, 0.9914707)]
# 11번째 문서의 토픽 분포는 [(2, 0.99107033)]
# 12번째 문서의 토픽 분포는 [(2, 0.99016917)]
# 13번째 문서의 토픽 분포는 [(4, 0.9801383)]
# 14번째 문서의 토픽 분포는 [(0, 0.9879214)]
# 15번째 문서의 토픽 분포는 [(1, 0.59123236), (3, 0.40195477)]
# 16번째 문서의 토픽 분포는 [(0, 0.5724271), (3, 0.4210419)]
# 17번째 문서의 토픽 분포는 [(1, 0.77325505), (3, 0.22174361)]
# 18번째 문서의 토픽 분포는 [(3, 0.9924369)]
# 19번째 문서의 토픽 분포는 [(1, 0.9919472)]
# 20번째 문서의 토픽 분포는 [(0, 0.01237789), (2, 0.98081714)]
# 21번째 문서의 토픽 분포는 [(2, 0.11695645), (3, 0.87669694)]
# 22번째 문서의 토픽 분포는 [(3, 0.9905345)]
# 23번째 문서의 토픽 분포는 [(0, 0.99191564)]
# 24번째 문서의 토픽 분포는 [(4, 0.9929967)]
# 25번째 문서의 토픽 분포는 [(1, 0.9924082)]
# 26번째 문서의 토픽 분포는 [(2, 0.9905495)]
# 27번째 문서의 토픽 분포는 [(2, 0.991889)]
# 28번째 문서의 토픽 분포는 [(3, 0.9898515)]
# 29번째 문서의 토픽 분포는 [(0, 0.78401196), (3, 0.20978418)]
# 30번째 문서의 토픽 분포는 [(0, 0.5187122), (1, 0.47391883)]
# 31번째 문서의 토픽 분포는 [(0, 0.8059453), (3, 0.18718047)]
# 32번째 문서의 토픽 분포는 [(4, 0.9906704)]
# 33번째 문서의 토픽 분포는 [(2, 0.99224526)]
# 34번째 문서의 토픽 분포는 [(2, 0.9917556)]
# 35번째 문서의 토픽 분포는 [(4, 0.98660314)]
# 36번째 문서의 토픽 분포는 [(0, 0.41881397), (2, 0.57522553)]
# 37번째 문서의 토픽 분포는 [(0, 0.9907028)]
# 38번째 문서의 토픽 분포는 [(0, 0.23398049), (1, 0.7561801)]
# 39번째 문서의 토픽 분포는 [(0, 0.22106352), (1, 0.77384925)]
# 40번째 문서의 토픽 분포는 [(0, 0.92438906), (3, 0.069850065)]
# 41번째 문서의 토픽 분포는 [(4, 0.9876301)]
# 42번째 문서의 토픽 분포는 [(0, 0.22515991), (2, 0.6302519), (3, 0.13993339)]
# 43번째 문서의 토픽 분포는 [(2, 0.9923118)]
# 44번째 문서의 토픽 분포는 [(3, 0.99201924)]
# 45번째 문서의 토픽 분포는 [(0, 0.117148206), (1, 0.10888675), (3, 0.7702127)]
# 46번째 문서의 토픽 분포는 [(1, 0.99280894)]
# 47번째 문서의 토픽 분포는 [(0, 0.23846279), (3, 0.75597465)]
# 48번째 문서의 토픽 분포는 [(3, 0.98995394)]
# 49번째 문서의 토픽 분포는 [(2, 0.8480232), (4, 0.14493033)]
# 50번째 문서의 토픽 분포는 [(1, 0.9906042)]
# 51번째 문서의 토픽 분포는 [(0, 0.98795563)]
# 52번째 문서의 토픽 분포는 [(2, 0.9914613)]
# 53번째 문서의 토픽 분포는 [(1, 0.4808373), (3, 0.5125926)]
# 54번째 문서의 토픽 분포는 [(1, 0.39081562), (2, 0.6017289)]
# 55번째 문서의 토픽 분포는 [(0, 0.6112483), (3, 0.3827346)]
# 56번째 문서의 토픽 분포는 [(0, 0.89937055), (3, 0.09203049)]
# 57번째 문서의 토픽 분포는 [(2, 0.99064076)]
# 58번째 문서의 토픽 분포는 [(0, 0.9932065)]
# 59번째 문서의 토픽 분포는 [(3, 0.99296653)]
# 60번째 문서의 토픽 분포는 [(0, 0.2407691), (1, 0.4338724), (2, 0.31886718)]
# 61번째 문서의 토픽 분포는 [(0, 0.9935042)]
# 62번째 문서의 토픽 분포는 [(3, 0.99184245)]
# 63번째 문서의 토픽 분포는 [(1, 0.14917558), (2, 0.100949064), (4, 0.7456726)]
# 64번째 문서의 토픽 분포는 [(3, 0.4447214), (4, 0.54813594)]
# 65번째 문서의 토픽 분포는 [(0, 0.7164053), (1, 0.27725753)]
# 66번째 문서의 토픽 분포는 [(2, 0.43013608), (3, 0.5646217)]
# 67번째 문서의 토픽 분포는 [(0, 0.9915704)]
# 68번째 문서의 토픽 분포는 [(0, 0.29366812), (4, 0.70171136)]
# 69번째 문서의 토픽 분포는 [(3, 0.9905917)]
# 70번째 문서의 토픽 분포는 [(3, 0.99322087)]
# 71번째 문서의 토픽 분포는 [(0, 0.9919276)]
# 72번째 문서의 토픽 분포는 [(0, 0.9892162)]
# 73번째 문서의 토픽 분포는 [(3, 0.9919562)]
# 74번째 문서의 토픽 분포는 [(0, 0.9914044)]
# 75번째 문서의 토픽 분포는 [(1, 0.99233276)]
# 76번째 문서의 토픽 분포는 [(2, 0.99273735)]
# 77번째 문서의 토픽 분포는 [(1, 0.99018836)]
# 78번째 문서의 토픽 분포는 [(3, 0.9908644)]
# 79번째 문서의 토픽 분포는 [(1, 0.98883533)]
# 80번째 문서의 토픽 분포는 [(0, 0.989075)]
# 81번째 문서의 토픽 분포는 [(0, 0.99246633)]
# 82번째 문서의 토픽 분포는 [(3, 0.9925808)]
# 83번째 문서의 토픽 분포는 [(1, 0.07949884), (2, 0.91347986)]
# 84번째 문서의 토픽 분포는 [(0, 0.9935702)]
# 85번째 문서의 토픽 분포는 [(1, 0.9838413)]
# 86번째 문서의 토픽 분포는 [(1, 0.9914642)]
# 87번째 문서의 토픽 분포는 [(1, 0.98576707)]
# 88번째 문서의 토픽 분포는 [(2, 0.78569734), (3, 0.20870899)]
# 89번째 문서의 토픽 분포는 [(2, 0.9921231)]
# 90번째 문서의 토픽 분포는 [(3, 0.99129283)]
# 91번째 문서의 토픽 분포는 [(0, 0.9927394)]
# 92번째 문서의 토픽 분포는 [(0, 0.99157095)]
# 93번째 문서의 토픽 분포는 [(0, 0.9915461)]
# 94번째 문서의 토픽 분포는 [(2, 0.19324832), (3, 0.8009296)]
# 95번째 문서의 토픽 분포는 [(1, 0.99038815)]
# 96번째 문서의 토픽 분포는 [(1, 0.5002559), (3, 0.49210215)]
# 97번째 문서의 토픽 분포는 [(1, 0.9942834)]
# 98번째 문서의 토픽 분포는 [(0, 0.99174106)]
# 99번째 문서의 토픽 분포는 [(3, 0.1371677), (4, 0.8561618)]
# 100번째 문서의 토픽 분포는 [(4, 0.9905165)]
# 101번째 문서의 토픽 분포는 [(0, 0.9885206)]
# 102번째 문서의 토픽 분포는 [(2, 0.99058133)]
# 103번째 문서의 토픽 분포는 [(2, 0.99192226)]
# 104번째 문서의 토픽 분포는 [(1, 0.9929994)]
# 105번째 문서의 토픽 분포는 [(1, 0.98872244)]
# 106번째 문서의 토픽 분포는 [(0, 0.44089437), (2, 0.5536772)]
# 107번째 문서의 토픽 분포는 [(1, 0.6359232), (3, 0.3558869)]
# 108번째 문서의 토픽 분포는 [(0, 0.9934752)]
# 109번째 문서의 토픽 분포는 [(0, 0.99296784)]
# 110번째 문서의 토픽 분포는 [(0, 0.9866637)]
# 111번째 문서의 토픽 분포는 [(2, 0.044784695), (3, 0.94830847)]
# 112번째 문서의 토픽 분포는 [(0, 0.26132095), (4, 0.73392284)]
# 113번째 문서의 토픽 분포는 [(0, 0.40617028), (3, 0.58414376)]
# 114번째 문서의 토픽 분포는 [(3, 0.99188507)]
# 115번째 문서의 토픽 분포는 [(3, 0.9903415)]
# 116번째 문서의 토픽 분포는 [(0, 0.9888435)]
# 117번째 문서의 토픽 분포는 [(3, 0.9924932)]
# 118번째 문서의 토픽 분포는 [(3, 0.99110734)]
# 119번째 문서의 토픽 분포는 [(0, 0.707271), (1, 0.28618878)]
# 120번째 문서의 토픽 분포는 [(0, 0.53611296), (1, 0.45799005)]
# 121번째 문서의 토픽 분포는 [(1, 0.99248916)]
# 122번째 문서의 토픽 분포는 [(1, 0.99231493)]
# 123번째 문서의 토픽 분포는 [(3, 0.98195004)]
# 124번째 문서의 토픽 분포는 [(3, 0.99289936)]
# 125번째 문서의 토픽 분포는 [(3, 0.98977447)]
# 126번째 문서의 토픽 분포는 [(0, 0.99284595)]
# 127번째 문서의 토픽 분포는 [(0, 0.036110245), (3, 0.95891577)]
# 128번째 문서의 토픽 분포는 [(2, 0.99414104)]
# 129번째 문서의 토픽 분포는 [(1, 0.99191904)]
# 130번째 문서의 토픽 분포는 [(4, 0.9927633)]
# 131번째 문서의 토픽 분포는 [(3, 0.9933876)]
# 132번째 문서의 토픽 분포는 [(0, 0.095170036), (1, 0.89558846)]
# 133번째 문서의 토픽 분포는 [(0, 0.77912736), (1, 0.21481289)]
# 134번째 문서의 토픽 분포는 [(0, 0.7709486), (3, 0.22381735)]
# 135번째 문서의 토픽 분포는 [(0, 0.9884376)]
# 136번째 문서의 토픽 분포는 [(2, 0.9897549)]
# 137번째 문서의 토픽 분포는 [(2, 0.102586694), (3, 0.8909131)]
# 138번째 문서의 토픽 분포는 [(2, 0.27954456), (3, 0.7147458)]
# 139번째 문서의 토픽 분포는 [(3, 0.99092275)]
# 140번째 문서의 토픽 분포는 [(4, 0.992128)]
# 141번째 문서의 토픽 분포는 [(0, 0.5000651), (1, 0.49272868)]
# 142번째 문서의 토픽 분포는 [(3, 0.99066114)]
# 143번째 문서의 토픽 분포는 [(2, 0.9892498)]
# 144번째 문서의 토픽 분포는 [(2, 0.99041414)]
# 145번째 문서의 토픽 분포는 [(2, 0.99281615)]
# 146번째 문서의 토픽 분포는 [(0, 0.9883595)]
# 147번째 문서의 토픽 분포는 [(1, 0.22266458), (2, 0.77027607)]
# 148번째 문서의 토픽 분포는 [(0, 0.32755572), (2, 0.6152462), (3, 0.05157876)]
# 149번째 문서의 토픽 분포는 [(0, 0.99147224)]
# 150번째 문서의 토픽 분포는 [(3, 0.99120224)]
# 151번째 문서의 토픽 분포는 [(3, 0.76423997), (4, 0.22423014)]
# 152번째 문서의 토픽 분포는 [(1, 0.99160403)]
# 153번째 문서의 토픽 분포는 [(3, 0.9916003)]
# 154번째 문서의 토픽 분포는 [(0, 0.99273455)]
# 155번째 문서의 토픽 분포는 [(2, 0.99209505)]
# 156번째 문서의 토픽 분포는 [(3, 0.9920232)]
# 157번째 문서의 토픽 분포는 [(0, 0.73810834), (1, 0.25428382)]
# 158번째 문서의 토픽 분포는 [(0, 0.12559476), (3, 0.8686137)]
# 159번째 문서의 토픽 분포는 [(0, 0.3143173), (2, 0.3407886), (3, 0.3391063)]
# 160번째 문서의 토픽 분포는 [(1, 0.9897514)]
# 161번째 문서의 토픽 분포는 [(2, 0.8012071), (3, 0.19308536)]
# 162번째 문서의 토픽 분포는 [(0, 0.99276423)]
# 163번째 문서의 토픽 분포는 [(2, 0.9790487)]
# 164번째 문서의 토픽 분포는 [(0, 0.99140817)]
# 165번째 문서의 토픽 분포는 [(0, 0.30437508), (1, 0.68914276)]
# 166번째 문서의 토픽 분포는 [(0, 0.990886)]
# 167번째 문서의 토픽 분포는 [(0, 0.7343714), (4, 0.25989464)]
# 168번째 문서의 토픽 분포는 [(1, 0.9932293)]
# 169번째 문서의 토픽 분포는 [(0, 0.9881917)]
# 170번째 문서의 토픽 분포는 [(0, 0.99236524)]
# 171번째 문서의 토픽 분포는 [(3, 0.98982316)]
# 172번째 문서의 토픽 분포는 [(2, 0.9878549)]
# 173번째 문서의 토픽 분포는 [(1, 0.40775275), (3, 0.5870384)]
# 174번째 문서의 토픽 분포는 [(4, 0.99302757)]
# 175번째 문서의 토픽 분포는 [(3, 0.9900425)]
# 176번째 문서의 토픽 분포는 [(0, 0.82092017), (3, 0.17250626)]
# 177번째 문서의 토픽 분포는 [(3, 0.9918271)]
# 178번째 문서의 토픽 분포는 [(2, 0.9906206)]
# 179번째 문서의 토픽 분포는 [(0, 0.98923826)]
# 180번째 문서의 토픽 분포는 [(1, 0.99262846)]
# 181번째 문서의 토픽 분포는 [(3, 0.9925508)]
# 182번째 문서의 토픽 분포는 [(0, 0.06422436), (2, 0.6513395), (3, 0.2786277)]
# 183번째 문서의 토픽 분포는 [(2, 0.63085073), (3, 0.36329898)]
# 184번째 문서의 토픽 분포는 [(1, 0.9927418)]
# 185번째 문서의 토픽 분포는 [(0, 0.040553853), (2, 0.8443385), (3, 0.11104814)]
# 186번째 문서의 토픽 분포는 [(1, 0.9916452)]
# 187번째 문서의 토픽 분포는 [(1, 0.46646023), (2, 0.5259469)]
# 188번째 문서의 토픽 분포는 [(0, 0.034423124), (2, 0.9601202)]
# 189번째 문서의 토픽 분포는 [(3, 0.9824675)]
# 190번째 문서의 토픽 분포는 [(2, 0.5865023), (3, 0.40780476)]
# 191번째 문서의 토픽 분포는 [(3, 0.99109846)]
# 192번째 문서의 토픽 분포는 [(4, 0.9894705)]
# 193번째 문서의 토픽 분포는 [(3, 0.9921384)]
# 194번째 문서의 토픽 분포는 [(0, 0.5902597), (2, 0.40252092)]
# 195번째 문서의 토픽 분포는 [(3, 0.99147797)]
# 196번째 문서의 토픽 분포는 [(0, 0.9920605)]
# 197번째 문서의 토픽 분포는 [(0, 0.1480455), (1, 0.83380556)]
# 198번째 문서의 토픽 분포는 [(1, 0.15479329), (3, 0.8397478)]
# 199번째 문서의 토픽 분포는 [(3, 0.9911382)]
# 200번째 문서의 토픽 분포는 [(1, 0.99086756)]
# 201번째 문서의 토픽 분포는 [(3, 0.9938025)]
# 202번째 문서의 토픽 분포는 [(0, 0.3658003), (1, 0.44442338), (3, 0.18429936)]
# 203번째 문서의 토픽 분포는 [(2, 0.987146)]
# 204번째 문서의 토픽 분포는 [(4, 0.9939975)]
# 205번째 문서의 토픽 분포는 [(2, 0.67669195), (3, 0.31612563)]
# 206번째 문서의 토픽 분포는 [(0, 0.9906947)]
# 207번째 문서의 토픽 분포는 [(4, 0.99291116)]
# 208번째 문서의 토픽 분포는 [(0, 0.36296248), (1, 0.6314704)]
# 209번째 문서의 토픽 분포는 [(4, 0.96613675)]
# 210번째 문서의 토픽 분포는 [(1, 0.6795304), (4, 0.31002563)]
# 211번째 문서의 토픽 분포는 [(0, 0.09934518), (3, 0.2684925), (4, 0.62791884)]
# 212번째 문서의 토픽 분포는 [(2, 0.99267274)]
# 213번째 문서의 토픽 분포는 [(0, 0.9905679)]
# 214번째 문서의 토픽 분포는 [(2, 0.98874927)]
# 215번째 문서의 토픽 분포는 [(0, 0.05598533), (1, 0.6499459), (3, 0.28841886)]
# 216번째 문서의 토픽 분포는 [(1, 0.99281067)]
# 217번째 문서의 토픽 분포는 [(2, 0.6795928), (3, 0.31494626)]
# 218번째 문서의 토픽 분포는 [(3, 0.9901275)]
# 219번째 문서의 토픽 분포는 [(1, 0.99126524)]
# 220번째 문서의 토픽 분포는 [(0, 0.58768266), (2, 0.4048362)]
# 221번째 문서의 토픽 분포는 [(2, 0.9909565)]
# 222번째 문서의 토픽 분포는 [(0, 0.9921605)]
# 223번째 문서의 토픽 분포는 [(1, 0.98993653)]
# 224번째 문서의 토픽 분포는 [(0, 0.9923966)]
# 225번째 문서의 토픽 분포는 [(2, 0.99469316)]
# 226번째 문서의 토픽 분포는 [(0, 0.57333124), (1, 0.42045826)]
# 227번째 문서의 토픽 분포는 [(1, 0.99275887)]
# 228번째 문서의 토픽 분포는 [(2, 0.7901386), (3, 0.20384052)]
# 229번째 문서의 토픽 분포는 [(2, 0.80080086), (3, 0.19443205)]
# 230번째 문서의 토픽 분포는 [(3, 0.9880901)]
# 231번째 문서의 토픽 분포는 [(2, 0.9903162)]
# 232번째 문서의 토픽 분포는 [(0, 0.020532139), (1, 0.9742376)]
# 233번째 문서의 토픽 분포는 [(0, 0.99282205)]
# 234번째 문서의 토픽 분포는 [(0, 0.9892453)]
# 235번째 문서의 토픽 분포는 [(0, 0.99044114)]
# 236번째 문서의 토픽 분포는 [(2, 0.60149515), (4, 0.3922625)]
# 237번째 문서의 토픽 분포는 [(0, 0.38882297), (1, 0.6055742)]
# 238번째 문서의 토픽 분포는 [(2, 0.98851)]
# 239번째 문서의 토픽 분포는 [(1, 0.5580803), (3, 0.43461612)]
# 240번째 문서의 토픽 분포는 [(3, 0.9910021)]
# 241번째 문서의 토픽 분포는 [(2, 0.9859475)]
# 242번째 문서의 토픽 분포는 [(3, 0.98891747)]
# 243번째 문서의 토픽 분포는 [(2, 0.9907344)]
# 244번째 문서의 토픽 분포는 [(3, 0.9909009)]
# 245번째 문서의 토픽 분포는 [(3, 0.9926993)]
# 246번째 문서의 토픽 분포는 [(3, 0.99223906)]
# 247번째 문서의 토픽 분포는 [(1, 0.8938168), (4, 0.09908721)]
# 248번째 문서의 토픽 분포는 [(2, 0.98933715)]
# 249번째 문서의 토픽 분포는 [(1, 0.49095082), (4, 0.5014403)]
# 250번째 문서의 토픽 분포는 [(2, 0.9875077)]
# 251번째 문서의 토픽 분포는 [(0, 0.9903858)]
# 252번째 문서의 토픽 분포는 [(3, 0.992599)]
# 253번째 문서의 토픽 분포는 [(3, 0.9903418)]
# 254번째 문서의 토픽 분포는 [(0, 0.37862003), (2, 0.61263585)]
# 255번째 문서의 토픽 분포는 [(3, 0.9923394)]
# 256번째 문서의 토픽 분포는 [(0, 0.58588946), (3, 0.40783396)]
# 257번째 문서의 토픽 분포는 [(0, 0.9926794)]
# 258번째 문서의 토픽 분포는 [(4, 0.9909328)]
# 259번째 문서의 토픽 분포는 [(1, 0.990909)]
# 260번째 문서의 토픽 분포는 [(0, 0.6821187), (1, 0.31199864)]
# 261번째 문서의 토픽 분포는 [(2, 0.7390278), (3, 0.25459003)]
# 262번째 문서의 토픽 분포는 [(0, 0.99040306)]
# 263번째 문서의 토픽 분포는 [(0, 0.9900968)]
# 264번째 문서의 토픽 분포는 [(3, 0.98977)]
# 265번째 문서의 토픽 분포는 [(0, 0.4262527), (1, 0.23745693), (3, 0.32765067)]
# 266번째 문서의 토픽 분포는 [(1, 0.99280214)]
# 267번째 문서의 토픽 분포는 [(2, 0.9902777)]
# 268번째 문서의 토픽 분포는 [(1, 0.98847264)]
# 269번째 문서의 토픽 분포는 [(0, 0.33815992), (4, 0.6552609)]
# 270번째 문서의 토픽 분포는 [(2, 0.99058115)]
# 271번째 문서의 토픽 분포는 [(1, 0.99132246)]
# 272번째 문서의 토픽 분포는 [(2, 0.99131787)]
# 273번째 문서의 토픽 분포는 [(0, 0.6749078), (1, 0.3146947)]
# 274번째 문서의 토픽 분포는 [(3, 0.993574)]
# 275번째 문서의 토픽 분포는 [(2, 0.57321346), (3, 0.41973868)]
# 276번째 문서의 토픽 분포는 [(0, 0.040129796), (2, 0.95272225)]
# 277번째 문서의 토픽 분포는 [(0, 0.9929711)]
# 278번째 문서의 토픽 분포는 [(3, 0.98411155)]
# 279번째 문서의 토픽 분포는 [(0, 0.9868973)]
# 280번째 문서의 토픽 분포는 [(2, 0.267734), (3, 0.72663176)]
# 281번째 문서의 토픽 분포는 [(3, 0.98885375)]
# 282번째 문서의 토픽 분포는 [(1, 0.98980117)]
# 283번째 문서의 토픽 분포는 [(0, 0.43589807), (4, 0.55691594)]
# 284번째 문서의 토픽 분포는 [(2, 0.98958695)]
# 285번째 문서의 토픽 분포는 [(0, 0.9895566)]
# 286번째 문서의 토픽 분포는 [(2, 0.7899443), (3, 0.20259584)]
# 287번째 문서의 토픽 분포는 [(3, 0.98786336)]
# 288번째 문서의 토픽 분포는 [(2, 0.9918481)]
# 289번째 문서의 토픽 분포는 [(0, 0.20695992), (2, 0.30694118), (3, 0.4800629)]
# 290번째 문서의 토픽 분포는 [(1, 0.7484382), (3, 0.24350208)]
# 291번째 문서의 토픽 분포는 [(1, 0.9914888)]
# 292번째 문서의 토픽 분포는 [(1, 0.99267673)]
# 293번째 문서의 토픽 분포는 [(0, 0.0798121), (2, 0.90925455)]
# 294번째 문서의 토픽 분포는 [(0, 0.99030906)]
# 295번째 문서의 토픽 분포는 [(1, 0.33856338), (3, 0.6555434)]
# 296번째 문서의 토픽 분포는 [(3, 0.9872184)]
# 297번째 문서의 토픽 분포는 [(0, 0.2063028), (1, 0.43270302), (3, 0.35762113)]
# 298번째 문서의 토픽 분포는 [(3, 0.9906435)]
# 299번째 문서의 토픽 분포는 [(0, 0.9902247)]
# 300번째 문서의 토픽 분포는 [(0, 0.99180466)]
# 301번째 문서의 토픽 분포는 [(4, 0.99228877)]
# 302번째 문서의 토픽 분포는 [(0, 0.36901033), (3, 0.6237177)]
# 303번째 문서의 토픽 분포는 [(1, 0.9901573)]
# 304번째 문서의 토픽 분포는 [(0, 0.433364), (3, 0.55667794)]
# 305번째 문서의 토픽 분포는 [(2, 0.98460853)]
# 306번째 문서의 토픽 분포는 [(2, 0.8668233), (3, 0.12538615)]
# 307번째 문서의 토픽 분포는 [(2, 0.7499107), (3, 0.23706575)]
# 308번째 문서의 토픽 분포는 [(2, 0.9921948)]
# 309번째 문서의 토픽 분포는 [(0, 0.7000083), (3, 0.29315627)]
# 310번째 문서의 토픽 분포는 [(4, 0.99060404)]
# 311번째 문서의 토픽 분포는 [(0, 0.9918342)]
# 312번째 문서의 토픽 분포는 [(2, 0.9891721)]
# 313번째 문서의 토픽 분포는 [(0, 0.99083006)]
# 314번째 문서의 토픽 분포는 [(0, 0.18124488), (2, 0.8114988)]
# 315번째 문서의 토픽 분포는 [(3, 0.9792545)]
# 316번째 문서의 토픽 분포는 [(0, 0.9876896)]
# 317번째 문서의 토픽 분포는 [(1, 0.9535559), (3, 0.03991669)]
# 318번째 문서의 토픽 분포는 [(0, 0.24376112), (1, 0.43261635), (3, 0.3196302)]
# 319번째 문서의 토픽 분포는 [(3, 0.99351394)]
# 320번째 문서의 토픽 분포는 [(3, 0.99180657)]
# 321번째 문서의 토픽 분포는 [(0, 0.4213294), (2, 0.38625637), (3, 0.18610018)]
# 322번째 문서의 토픽 분포는 [(0, 0.99351794)]
# 323번째 문서의 토픽 분포는 [(2, 0.982994)]
# 324번째 문서의 토픽 분포는 [(0, 0.43175334), (1, 0.5611568)]
# 325번째 문서의 토픽 분포는 [(0, 0.25243732), (3, 0.7395753)]
# 326번째 문서의 토픽 분포는 [(0, 0.99031657)]
# 327번째 문서의 토픽 분포는 [(0, 0.99257797)]
# 328번째 문서의 토픽 분포는 [(4, 0.9916386)]
# 329번째 문서의 토픽 분포는 [(3, 0.9928516)]
# 330번째 문서의 토픽 분포는 [(1, 0.7594133), (4, 0.23253007)]
# 331번째 문서의 토픽 분포는 [(3, 0.8879154), (4, 0.10530419)]
# 332번째 문서의 토픽 분포는 [(0, 0.17331721), (1, 0.34902394), (2, 0.19292924), (3, 0.28237563)]
# 333번째 문서의 토픽 분포는 [(1, 0.58324), (3, 0.40449283)]
# 334번째 문서의 토픽 분포는 [(4, 0.9886825)]
# 335번째 문서의 토픽 분포는 [(0, 0.9928824)]
# 336번째 문서의 토픽 분포는 [(3, 0.678266), (4, 0.31338024)]
# 337번째 문서의 토픽 분포는 [(0, 0.6575603), (3, 0.33484158)]
# 338번째 문서의 토픽 분포는 [(3, 0.9908368)]
# 339번째 문서의 토픽 분포는 [(3, 0.9894509)]
# 340번째 문서의 토픽 분포는 [(0, 0.70301217), (2, 0.2885286)]
# 341번째 문서의 토픽 분포는 [(0, 0.9814284)]
# 342번째 문서의 토픽 분포는 [(0, 0.9801555)]
# 343번째 문서의 토픽 분포는 [(1, 0.08018041), (3, 0.9138233)]
# 344번째 문서의 토픽 분포는 [(1, 0.99318)]
# 345번째 문서의 토픽 분포는 [(0, 0.98836184)]
# 346번째 문서의 토픽 분포는 [(0, 0.28503054), (1, 0.39802906), (3, 0.3110711)]
# 347번째 문서의 토픽 분포는 [(1, 0.9880001)]
# 348번째 문서의 토픽 분포는 [(0, 0.7020487), (3, 0.29176927)]
# 349번째 문서의 토픽 분포는 [(3, 0.9884965)]
# 350번째 문서의 토픽 분포는 [(3, 0.9864198)]
# 351번째 문서의 토픽 분포는 [(0, 0.47182825), (3, 0.51710737)]
# 352번째 문서의 토픽 분포는 [(3, 0.99120176)]
# 353번째 문서의 토픽 분포는 [(1, 0.991827)]
# 354번째 문서의 토픽 분포는 [(2, 0.9833455)]
# 355번째 문서의 토픽 분포는 [(1, 0.43225527), (3, 0.5593486)]
# 356번째 문서의 토픽 분포는 [(1, 0.38535815), (2, 0.60580343)]
# 357번째 문서의 토픽 분포는 [(0, 0.9831082)]
# 358번째 문서의 토픽 분포는 [(0, 0.99018997)]
# 359번째 문서의 토픽 분포는 [(0, 0.43392244), (4, 0.5599257)]
# 360번째 문서의 토픽 분포는 [(3, 0.9904299)]
# 361번째 문서의 토픽 분포는 [(3, 0.99148935)]
# 362번째 문서의 토픽 분포는 [(0, 0.9880739)]

# %%
# 알 수 있는 것 2
topics = ldamodel.print_topics(num_words=30)

for topic in topics:
    print(topic)
# Out:
# (0, '0.019*"mandibular" + 0.015*"skeletal" + 0.013*"Class" + 0.013*"group" + 0.010*"study" + 0.010*"treatment" + 0.009*"III" + 0.008*"orthodontic" + 0.008*"significant" + 0.007*"surgery" + 0.007*"arch" + 0.007*"dental" + 0.006*"maxillary" + 0.006*"anterior" + 0.006*"vertical" + 0.006*"p" + 0.006*"facial" + 0.006*"plane" + 0.006*"CBCT" + 0.005*"posterior" + 0.005*"malocclusion" + 0.005*"asymmetry" + 0.005*"age" + 0.005*"mm" + 0.005*"<" + 0.004*"lingual" + 0.004*"mean" + 0.004*"length" + 0.004*"II" + 0.004*"tomography"')
# (1, '0.016*"treatment" + 0.015*"group" + 0.015*"%" + 0.015*"orthodontic" + 0.008*"bracket" + 0.007*"study" + 0.007*"SBS" + 0.006*"<" + 0.006*"p" + 0.005*"surface" + 0.005*"significant" + 0.005*"resin" + 0.005*"different" + 0.005*"bond" + 0.005*"strength" + 0.004*"system" + 0.004*"conventional" + 0.004*"control" + 0.004*"adhesive" + 0.004*"bonding" + 0.004*"]" + 0.004*"self-ligating" + 0.004*"wire" + 0.003*"time" + 0.003*"slot" + 0.003*"=" + 0.003*"method" + 0.003*"[" + 0.003*"metal" + 0.003*"retainer"')
# (2, '0.016*"treatment" + 0.016*"group" + 0.011*"maxillary" + 0.009*"orthodontic" + 0.009*"p" + 0.008*"study" + 0.008*"significant" + 0.008*"<" + 0.007*"mm" + 0.007*"molar" + 0.006*"bone" + 0.005*"first" + 0.005*"dental" + 0.005*"width" + 0.005*"force" + 0.005*"movement" + 0.005*"expansion" + 0.004*"second" + 0.004*"mean" + 0.004*"malocclusion" + 0.004*"angle" + 0.004*"stress" + 0.004*"mandibular" + 0.004*"palatal" + 0.003*"analysis" + 0.003*"effect" + 0.003*"skeletal" + 0.003*"%" + 0.003*"length" + 0.003*"displacement"')
# (3, '0.022*"maxillary" + 0.014*"treatment" + 0.013*"bone" + 0.012*"Class" + 0.012*"group" + 0.010*"p" + 0.009*"mm" + 0.009*"study" + 0.009*"alveolar" + 0.008*"mandibular" + 0.008*"II" + 0.007*"orthodontic" + 0.007*"anterior" + 0.007*"dental" + 0.007*"incisor" + 0.007*"CBCT" + 0.006*"<" + 0.006*"molar" + 0.006*"significant" + 0.006*"facial" + 0.005*"malocclusion" + 0.005*"root" + 0.005*"arch" + 0.005*"lip" + 0.005*"buccal" + 0.004*"lateral" + 0.004*"thickness" + 0.004*"age" + 0.004*"first" + 0.004*"central"')
# (4, '0.014*"group" + 0.009*"bone" + 0.007*"orthodontic" + 0.007*"%" + 0.007*"PDL" + 0.007*"force" + 0.006*"movement" + 0.006*"cleft" + 0.005*"Group" + 0.005*"]" + 0.005*"<" + 0.005*"study" + 0.005*"[" + 0.005*"CP" + 0.004*"male" + 0.004*"significant" + 0.004*"treatment" + 0.004*"p" + 0.004*"stem" + 0.004*"TMJ" + 0.004*"torque" + 0.003*"expansion" + 0.003*"rate" + 0.003*"acid" + 0.003*"tooth" + 0.003*"period" + 0.003*"analysis" + 0.003*"insertion" + 0.003*"bilateral" + 0.003*"type"')

# %%
# 필요 없는 단어를 제거하기 

def remove_words(doc):
    remove_list = ['group', 'significant', '<', 'p', 'study', '=', '%', 'mm']
    result = [x for x in doc if x not in remove_list]
    return result

# %%
docs = docs.map(remove_words)

# %%
# 단어사전만들기
dictionary = corpora.Dictionary(docs)

# A B C D E ... P


# 단어사전을 이용한 정수인코딩

#      A B C D E ... P
# doc1 1 0 1 1 0 ... 1
# doc2 ...
corpus = [dictionary.doc2bow(doc) for doc in docs]

# %%
# %%time

# 다시 한번 학습
from gensim.models.ldamodel import LdaModel

NUM_TOPICS = 5

# 
ldamodel = LdaModel(corpus=corpus,
                    id2word=dictionary,
                    num_topics=NUM_TOPICS,
                    chunksize=363,
                    passes=20,
                    alpha='auto')
